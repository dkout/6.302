# %%
setwd('OneDrive/MIT/Senior Spring/6.302/Project/')
# Out:
# Error in setwd("OneDrive/MIT/Senior Spring/6.302/Project/"): cannot change working directory
# Traceback:
#
# 1. setwd("OneDrive/MIT/Senior Spring/6.302/Project/")

# %%
good_robot = read.csv(file="RobotPlot_bad.csv", header=FALSE, sep="\t")
bad_robot = read.csv(file = "robot_initial.csv", header=FALSE, sep="," )

# %%
colorvec <- c("dodgerblue2","#E31A1C", # red
                "green4",
                "#6A3D9A", # purple
                "#FF7F00", # orange
                "black","gold1",
                "skyblue2","#FB9A99", # lt pink
                "palegreen2",
                "gray70", "khaki2",
                "maroon","orchid1","deeppink1","blue1","steelblue4",
                "darkturquoise","green1","yellow4","yellow3",
                "darkorange4")

# %%
matplot(good_robot[350:2000,]*5*1.4/300, lty=1, lwd=1, type='l', main = "Final Gains", 
        xlab = "Timestep", ylab='Motor Command [V]', col = colorvec)
legend("topright", c("Angle", "Angle Rate", "Distance", "Distance Rate"),
      col = colorvec, lty=1, lwd=3)
# Out:
# Plot with title "Final Gains"

# %%
matplot(bad_robot[100:1800,]*5*1.4/300, lty=1, lwd=1, type='l', main = "Initial Gains", 
        xlab = "Timestep", ylab='Motor Command [V]', col = colorvec)
legend("topright", c("Angle", "A0ngle Rate", "Distance", "Distance Rate"),
      col = colorvec, lty=1, lwd=3)
# Out:
# Plot with title "Initial Gains"
